# %%
# 1. Setup
# AWQ Baseline Quantization on OPT-1.3B
# Metaheuristic Quantization vs AWQ – Baseline Quantization Phase

# Install core dependencies and clone the AWQ repo
# !pip install --quiet git+https://github.com/mit-han-lab/llm-awq.git
# !pip install --quiet transformers datasets accelerate

#  avoid installing flash-attn which causes many build errors

# 2. Download the model locally (this avoids model_path errors)
from transformers import AutoTokenizer, AutoModelForCausalLM
AutoTokenizer.from_pretrained("facebook/opt-1.3b")
AutoModelForCausalLM.from_pretrained("facebook/opt-1.3b")

# 3. Run simulated quantization using AWQ (no kernel building or flash-attn needed)
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# !python -m awq.entry \
  --model_path facebook/opt-1.3b \
  --tasks wikitext \
  --w_bit 4 \
  --q_group_size 128 \
  --run_awq \
  --q_backend fake \
  --dump_awq awq_cache/opt13b-w4-g128.pt
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.6/152.6 kB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
# WARNING: The candidate selected for download or install is a yanked version: 'transformers' candidate (version 4.46.0 at https://files.pythonhosted.org/packages/db/88/1ef8a624a33d7fe460a686b9e0194a7916320fc0d67d4e38e570beeac039/transformers-4.46.0-py3-none-any.whl (from https://pypi.org/simple/transformers/) (requires-python:>=3.8.0))
# Reason for being yanked: This version unfortunately does not work with 3.8 but we did not drop the support yet
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 12.2 MB/s eta 0:00:00
# ...
